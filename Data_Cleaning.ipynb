# %% [markdown]
# Running the cells below to install relevant packages and load the dataset.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler

df = pd.read_csv('./PS_20174392719_1491204439457_log (1).csv')

# %%
df.dtypes
# Out:
# step                int64
# type                  str
# amount            float64
# nameOrig              str
# oldbalanceOrg     float64
# newbalanceOrig    float64
# nameDest              str
# oldbalanceDest    float64
# newbalanceDest    float64
# isFraud             int64
# isFlaggedFraud      int64
# dtype: object

# %% [markdown]
# Dropping columns that are likely irrelevant to future machine learning.
# Step doesn't seem to provide relevant information (the time of the transaction), and the names of the account of original or destination are not relevant.

# %%
df.drop(["step","nameOrig","nameDest"], axis=1)
# Out:
#              type      amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# 0         PAYMENT     9839.64      170136.00       160296.36            0.00
# 1         PAYMENT     1864.28       21249.00        19384.72            0.00
# 2        TRANSFER      181.00         181.00            0.00            0.00
# 3        CASH_OUT      181.00         181.00            0.00        21182.00
# 4         PAYMENT    11668.14       41554.00        29885.86            0.00
# ...           ...         ...            ...             ...             ...
# 6362615  CASH_OUT   339682.13      339682.13            0.00            0.00
# 6362616  TRANSFER  6311409.28     6311409.28            0.00            0.00
# 6362617  CASH_OUT  6311409.28     6311409.28            0.00        68488.84
# 6362618  TRANSFER   850002.52      850002.52            0.00            0.00
# 6362619  CASH_OUT   850002.52      850002.52            0.00      6510099.11
#
# ...

# %%
#df = df.rename(columns={'oldbalanceOrg': 'old_balance_orig', 'newbalanceOrig': 'new_balance_orig'})

# %%
print(df.columns)
# Out:
# Index(['step', 'type', 'amount', 'nameOrig', 'oldbalanceOrg', 'newbalanceOrig',
#        'nameDest', 'oldbalanceDest', 'newbalanceDest', 'isFraud',
#        'isFlaggedFraud'],
#       dtype='str')

# %%
duplicate_rows_df = df[df.duplicated()]
print("number of duplicate rows: ", duplicate_rows_df.shape)
# Out:
# number of duplicate rows:  (0, 11)
